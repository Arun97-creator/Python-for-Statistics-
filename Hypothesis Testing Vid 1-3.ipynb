# %%
from IPython.display import Image

# %%
Image("E:/one.jpg")

# %%
from scipy import stats

# %%
#Finding P-value
stats.norm.cdf(-1.46)
# Out:
# 0.07214503696589378

# %%
#Finding Z-value 
stats.norm.ppf(0.1)

# Using z-value [ z calculated > z critical ] so reject
# Out:
# -1.2815515655446004

# %%
Image("E:/two.jpg")

# %%
# P-value approach
1-stats.norm.cdf(1.75)
# Out:
# 0.040059156863817114

# %%
#P-value
1-stats.norm.cdf(2.29)
# Out:
# 0.011010658324411393

# %%
Image("E:/three.jpg")

# %%
# Z table value at alpha =.10
stats.norm.ppf(0.1)
# Out:
# -1.2815515655446004

# %%
Image("E:/four.jpg")

# %%
# Z table value at alpha =.05
stats.norm.ppf(0.95)
# Out:
# 1.6448536269514722

# %%
Image("E:/five.jpg")

# %%
Image("E:/six.jpg")

# %%
1-stats.norm.cdf(2.74)
# Out:
# 0.003071959218650444

# %%
(1-stats.norm.cdf(2.74))*2
# Out:
# 0.006143918437300888

# %%
Image("E:/seven.jpg")

# %%
Image("E:/eight.jpg")

# %%
# Z table value at alpha =.015
stats.norm.ppf(0.015)
# Out:
# -2.1700903775845606

# %%
stats.norm.ppf(0.985)
# Out:
# 2.17009037758456

# %%
Image("E:/nine.jpg")

# %%
#Introduction of t-test
Image("E:/ten.jpg")

# %%
# Two-Test
Image("E:/eleven.jpg")

# %%
import numpy as np
x=[10,12,20,21,22,24,18,15]
stats.ttest_1samp(x,15)
# p-value = 0.162178 > 0.05 , so do not reject the null-hypothesis
# Out:
# Ttest_1sampResult(statistic=1.5623450931857947, pvalue=0.1621787560592894)

# %%
Image("E:/twelve.jpg")

# %%
# in t-test d.o.f is (n-1)
X=[13,8,10,10,8,9,10,11,6,8,12,11,11,12,10,12,7,10,11,8]

stats.ttest_1samp(X,10)
# Since it is right-tail test & we get t = -0.35843 is the left sided value , so there is a right positive value t=0.35843 
# pvalue=0.7239703579 is the combined area , so we have to divide by 2 , to get p-value for the right
# Out:
# Ttest_1sampResult(statistic=-0.35843385854878496, pvalue=0.7239703579964252)

# %%
0.723970357/2
# 0.3619 larger than 0.05 , we do not reject the null-hypothesis
# Out:
# 0.3619851785

# %%
Image("E:/thirteen.jpg")

# %%
stats.t.cdf(-0.3619851785,19)
# Out:
# 0.36067891561168275

# %%
#t-table value = one tail value for right check pg.116 gujrati
stats.t.ppf(0.05,11)
# Out:
# -1.7958848187036696

# %%
stats.t.ppf(0.025,11)
# for Two tail table Value  - alpha/2 - two values ( -2.2009  and  + 2.2009)
# Out:
# -2.200985160082949

# %%
Image("E:/fourteen.jpg")

# %%
Image("E:/fifteen.jpg")

# %%
Image("E:/sixteen.jpg")

# %%
from statsmodels.stats.proportion import proportions_ztest

count = 67

samplesize = 120
p = 0.5

proportions_ztest(count,samplesize,p)
# z-value and p-value
# Out:
# (1.286806739751111, 0.1981616572238455)

# %%
Image("E:/seventeen.jpg")
